# %%
import json

# Lendo o JSON
with open("retornoJSON/anderson_tracks.json", "r", encoding="utf-8") as f:
    tracks_data = json.load(f)

# Se o JSON for um dicionário com a lista dentro de "items", ajusta automaticamente
if isinstance(tracks_data, dict):
    if "items" in tracks_data:
        tracks = tracks_data["items"]
    else:
        # tenta achar a primeira lista dentro do dicionário
        tracks = next((v for v in tracks_data.values() if isinstance(v, list)), [])
else:
    tracks = tracks_data

result_list = []

# Itera somente nas 10 primeiras faixas
for track in tracks[:10]:
    result_list.append({
        "track_id": track.get("id"),
        "track_name": track.get("name"),
        "artist": track["artists"][0]["name"] if track.get("artists") else None,
        "artist_id": track["artists"][0]["id"] if track.get("artists") else None,
        "artist_image": None,
        "album": track["album"]["name"] if track.get("album") else None,
        "album_image": track["album"]["images"][0]["url"] if track.get("album") and track["album"].get("images") else None,
        "popularity": track.get("popularity")
    })

print(json.dumps(result_list, indent=2, ensure_ascii=False))

# %%
# UTILIZA GEMINI PARA ENRIQUECIMENTO DAS 10 PRIMEIRAS MÚSICAS

import os
from google import genai
import json
import re

# Configuração da chave
os.environ["GOOGLE_SECRET_API_KEY"] = "AIzaSyAtr3Mo8sDr36QB1MjRTEb4pDbOFAifAXA"
google_api_key = os.environ['GOOGLE_SECRET_API_KEY']

client = genai.Client(api_key=google_api_key)

test_batch = result_list

prompt = f"""
Você é um especialista em música. 
Para cada música listada abaixo, retorne em JSON os seguintes campos:

- track_id
- track_name
- artist
- album
- genre (gênero principal)
- subgenre (subgênero, se aplicável)
- danceability (0-1)
- energy (0-1)
- mood (ex.: energetic, calm, happy, sad)
- release_year (ano do lançamento, se conhecido)
- era (década: 1980s, 1990s, 2000s, 2010s, 2020s)
- lyrics_theme (tema predominante da letra, se conhecido)
- instrumentalness (0-1, grau de instrumentalidade)
- explicit (True/False)

Se algum valor for desconhecido, preencha com uma aproximação baseada no gênero da música.

Músicas:
{test_batch}

Devolva apenas o JSON como lista de objetos, sem explicações adicionais.
"""
client = genai.Client(api_key=google_api_key)

response = client.models.generate_content(model="gemini-2.5-flash", contents=[prompt])

response.text
# Out:
# '```json\n[\n  {\n    "track_id": "3wtmfJg7Y59193gisXjdmR",\n    "track_name": "RAGE",\n    "artist": "PRESIDENT",\n    "album": "RAGE",\n    "genre": "Electronic",\n    "subgenre": "Future House",\n    "danceability": 0.82,\n    "energy": 0.90,\n    "mood": "Energetic",\n    "release_year": 2023,\n    "era": "2020s",\n    "lyrics_theme": "Intensity, party, driving beat",\n    "instrumentalness": 0.45,\n    "explicit": false\n  },\n  {\n    "track_id": "22G1qJ4U8IcEufEEAbLroV",\n    "track_name": "Take What You Want",\n    "artist": "Yellowcard",\n    "album": "Better Days",\n    "genre": "Pop Punk",\n    "subgenre": "Alternative Rock",\n    "danceability": 0.65,\n    "energy": 0.85,\n    "mood": "Energetic",\n    "release_year": 2023,\n    "era": "2020s",\n    "lyrics_theme": "Relationships, defiance, self-assertion",\n    "instrumentalness": 0.20,\n    "explicit": false\n  },\n  {\n    "track_id": "3xQSG1eYo06kXI3JkPKllf",\n    "track_name": "In the Name of the Father",\n    "artist": "PRESIDENT",\n    "album": "In the Name of the Father",\n    "genre": "Electronic",\n    "subgenre": "Progressive House",\n    "danceability": 0.75,\n    "energy": 0.88,\n    "mood": "Epic",\n    "release_year": 2023,\n    "era": "2020s",\n    "lyrics_theme": "Dramatic, spiritual, abstract",\n    "instrumentalness": 0.60,\n    "explicit": false\n  },\n  {\n    "track_id": "6mCjOSXkABONouTVa6PQOy",\n    "track_name": "Tell That Mick He Just Made My List of Things to Do Today",\n    "artist": "Fall Out Boy",\n    "album": "Take This to Your Grave",\n    "genre": "Pop Punk",\n    "subgenre": "Emo",\n    "danceability": 0.60,\n    "energy": 0.92,\n    "mood": "Angsty",\n    "release_year": 2003,\n    "era": "2000s",\n    "lyrics_theme": "Defiance, relationships, revenge",\n    "instrumentalness": 0.18,\n    "explicit": false\n  },\n  {\n    "track_id": "21tuvt3CXIsNquc32v8jpc",\n    "track_name": "Show Me How to Live",\n    "artist": "Audioslave",\n    "album": "Audioslave",\n    "genre": "Alternative Rock",\n    "subgenre": "Hard Rock",\n    "danceability": 0.45,\n    "energy": 0.89,\n    "mood": "Intense",\n    "release_year": 2002,\n    "era": "2000s",\n    "lyrics_theme": "Existentialism, struggle, defiance",\n    "instrumentalness": 0.25,\n    "explicit": false\n  },\n  {\n    "track_id": "2zv8VuCCLdcSIefH3BOeuu",\n    "track_name": "Já Que Me Ensinou a Beber",\n    "artist": "Os Barões Da Pisadinha",\n    "album": "Você Não Me Deu Moral",\n    "genre": "Piseiro",\n    "subgenre": "Forró Eletrônico",\n    "danceability": 0.88,\n    "energy": 0.78,\n    "mood": "Happy",\n    "release_year": 2021,\n    "era": "2020s",\n    "lyrics_theme": "Heartbreak, drinking, relationships",\n    "instrumentalness": 0.10,\n    "explicit": false\n  },\n  {\n    "track_id": "2655xYZ347fG2N6OjkoMQ8",\n    "track_name": "Logo Eu",\n    "artist": "Jorge & Mateus",\n    "album": "Os Anjos Cantam",\n    "genre": "Sertanejo",\n    "subgenre": "Sertanejo Universitário",\n    "danceability": 0.62,\n    "energy": 0.70,\n    "mood": "Romantic",\n    "release_year": 2014,\n    "era": "2010s",\n    "lyrics_theme": "Love, longing, heartbreak",\n    "instrumentalness": 0.08,\n    "explicit": false\n  },\n  {\n    "track_id": "6wqJeItl3Vc3az4ZicSQAB",\n    "track_name": "Before I Forget",\n    "artist": "Slipknot",\n    "album": "Vol. 3: The Subliminal Verses (Special Edition)",\n    "genre": "Nu Metal",\n    "subgenre": "Alternative Metal",\n    "danceability": 0.40,\n    "energy": 0.95,\n    "mood": "Aggressive",\n    "release_year": 2004,\n    "era": "2000s",\n    "lyrics_theme": "Inner turmoil, rage, defiance",\n    "instrumentalness": 0.30,\n    "explicit": true\n  },\n  {\n    "track_id": "5sdqwzp1kSHHqTFsyfhrZW",\n    "track_name": "Destroy Me",\n    "artist": "PRESIDENT",\n    "album": "Destroy Me",\n    "genre": "Electronic",\n    "subgenre": "Tech House",\n    "danceability": 0.80,\n    "energy": 0.87,\n    "mood": "Intense",\n    "release_year": 2023,\n    "era": "2 ...

# %%
import json
import re

raw_text = response.text

# Remove markdown ```json ``` e aspas escapadas
clean_text = re.sub(r"```json|```", "", raw_text).replace('\\"', '"').strip()

# Regex para capturar todos os objetos {...} individualmente
matches = re.findall(r"\{.*?\}", clean_text, re.DOTALL)

enriched_tracks = []
for m in matches:
    try:
        obj = json.loads(m)
        enriched_tracks.append(obj)
    except json.JSONDecodeError:
        # Se falhar, podemos tentar corrigir vírgulas ou caracteres problemáticos
        m_fixed = re.sub(r",\s*}", "}", m)  # remove vírgulas finais
        m_fixed = re.sub(r",\s*\]", "]", m_fixed)  # remove vírgulas antes de colchetes
        try:
            obj = json.loads(m_fixed)
            enriched_tracks.append(obj)
        except json.JSONDecodeError:
            print("⚠️ Objeto ignorado por JSON inválido:", m[:60], "...")

print(f"✅ Total de objetos válidos: {len(enriched_tracks)}")

# Salva em arquivo JSON
if enriched_tracks:
    output_file = "retornoJSON/anderson_tracks_enriched.json"
    with open(output_file, "w", encoding="utf-8") as f:
        json.dump(enriched_tracks, f, ensure_ascii=False, indent=2)
    print(f"✅ Arquivo salvo em {output_file}")
# Out:
# ✅ Total de objetos válidos: 10
# ✅ Arquivo salvo em retornoJSON/anderson_tracks_enriched.json

# %%
#%pip install scikit-learn

# %%
#compara utilizando modelo 

import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# ===============================
# 1️⃣ Ler arquivos JSON
# ===============================
base_geral = pd.read_json("retornoJSON/df_tracks_enriched.json")
base_usuario = pd.read_json("retornoJSON/anderson_tracks_enriched.json")

# ===============================
# 2️⃣ Selecionar features relevantes
# ===============================
features_numericas = ['danceability', 'energy', 'instrumentalness']
features_textuais = ['genre', 'subgenre', 'mood', 'lyrih_cs_theme']

# ===============================
# 3️⃣ Normalizar features numéricas
# ===============================
scaler = StandardScaler()
X_base_num = scaler.fit_transform(base_geral[features_numericas])
X_user_num = scaler.transform(base_usuario[features_numericas])

# ===============================
# 4️⃣ Transformar textos em vetores TF-IDF
# ===============================
def combinar_textos(df):
    return (
        df['genre'].fillna('') + ' ' +
        df['subgenre'].fillna('') + ' ' +
        df['mood'].fillna('') + ' ' +
        df['lyrics_theme'].fillna('')
    )

tfidf = TfidfVectorizer(stop_words='english')
X_base_text = tfidf.fit_transform(combinar_textos(base_geral))
X_user_text = tfidf.transform(combinar_textos(base_usuario))

# ===============================
# 5️⃣ Combinar representações numéricas + textuais
# ===============================
from scipy.sparse import hstack

X_base_total = hstack([X_base_text, X_base_num])
X_user_total = hstack([X_user_text, X_user_num])

# ===============================
# 6️⃣ Calcular similaridade de cosseno
# ===============================
similaridade = cosine_similarity(X_user_total, X_base_total)

# média da similaridade de todas as músicas do usuário
media_sim = similaridade.mean(axis=0)

# ===============================
# 7️⃣ Ordenar top recomendações
# ===============================
base_geral['similaridade'] = media_sim
recomendacoes = base_geral.sort_values('similaridade', ascending=False)

# ===============================
# 8️⃣ Exibir top 10 músicas recomendadas
# ===============================
cols = ['track_name', 'artist', 'album', 'genre', 'subgenre', 'similaridade']
recomendacoes[cols].head(5)
# Out:
#                         track_name               artist  \
# 247                      Sandstorm               Darude
# 36           La Plena - W Sound 05              W Sound
# 333  Barbra Streisand - Radio Edit           Duck Sauce
# 314   One (Your Name) - Radio Edit  Swedish House Mafia
# 43               The Addams Family          Andrew Gold
#
#                                   album       genre  \
# 247   Before the Storm, Special Edition      Trance
# 36                La Plena (W Sound 05)  Electronic
# 333                    Barbra Streisand  Electronic
# 314                     One (Your Name)  Electronic
# 43   Halloween Howls: Fun & Scary Music     Novelty
#
#                             subgenre  similaridade
# 247  Hard Trance, Progressive Trance      0.536337
# 36                  Afro House/Dance      0.530789
# 333                      Disco House      0.518321
# 314                Progressive House      0.512859
# 43                      Instrumental      0.494233

# %%
# Salva o resultado de recomendacoes[cols].head(5) em um arquivo .json
recomendacoes[cols].head(5).to_json(
    "retornoJSON/recommendation_anderson.json",
    orient="records",
    force_ascii=False,
    indent=2
)
