# %%
import json

# Lendo o JSON
with open("retornoJSON/nilton_tracks.json", "r", encoding="utf-8") as f:
    tracks_data = json.load(f)

# Se o JSON for um dicionário com a lista dentro de "items", ajusta automaticamente
if isinstance(tracks_data, dict):
    if "items" in tracks_data:
        tracks = tracks_data["items"]
    else:
        # tenta achar a primeira lista dentro do dicionário
        tracks = next((v for v in tracks_data.values() if isinstance(v, list)), [])
else:
    tracks = tracks_data

result_list = []

# Altera somente nas 10 primeiras faixas
for track in tracks[:10]:
    result_list.append({
        "track_id": track.get("id"),
        "track_name": track.get("name"),
        "artist": track["artists"][0]["name"] if track.get("artists") else None,
        "artist_id": track["artists"][0]["id"] if track.get("artists") else None,
        "artist_image": None,
        "album": track["album"]["name"] if track.get("album") else None,
        "album_image": track["album"]["images"][0]["url"] if track.get("album") and track["album"].get("images") else None,
        "popularity": track.get("popularity")
    })

print(json.dumps(result_list, indent=2, ensure_ascii=False))
# Out:
# [
#   {
#     "track_id": "1yZBuUYcA0Ug7Y7ImNdhwt",
#     "track_name": "Zodiac",
#     "artist": "Agents Of Time",
#     "artist_id": "6Jbyd4qzEtbFtswZP1o6Ht",
#     "artist_image": null,
#     "album": "Zodiac",
#     "album_image": "https://i.scdn.co/image/ab67616d0000b273d404fdcb86d0416c22764a77",
#     "popularity": 51
#   },
#   {
#     "track_id": "2SbAoNQVqVkIuFTFV94Bdm",
#     "track_name": "Make It Better [ZAC & BAKKA (BR) Remix]",
#     "artist": "Dashdot",
#     "artist_id": "0dDnvI6TCQslhEBYCA4DPU",
#     "artist_image": null,
#     "album": "Make It Better (Remixes Vol.1)",
#     "album_image": "https://i.scdn.co/image/ab67616d0000b273d65b70a6fc2215876ff53ec4",
#     "popularity": 54
#   },
#   {
#     "track_id": "4vLdWFBi8WgA00nWPUHaLS",
#     "track_name": "All That Matters - ARTBAT Remix Radio Edit",
#     "artist": "Kölsch",
#     "artist_id": "2D9Oe8R9UhbMvFAsMJpXj0",
#     "artist_image": null,
#     "album": "All That Matters (Artbat Remix)",
#     "album_image": "https://i.scdn.co/image/ab67616d0000b273cf1870357fb870664183e1e3",
#     "popularity": 48
#   },
#   {
#     "track_id": "6jYXP1jrYIHkEYglFgeL2Q",
#     "track_name": "Home",
#     "artist": "Adriatique",
#     "artist_id": "02DWGcShQivFepRvGJ7xhB",
#     "artist_image": null,
#     "album": "Home",
#     "album_image": "https://i.scdn.co/image/ab67616d0000b273c440c427668303a3354e4fd8",
#     "popularity": 61
#   },
#   {
#     "track_id": "1G3kwVs3JHqN5UPiFXcAID",
#     "track_name": "Moth To A Flame (feat. The Weeknd) - Adriatique Remix",
#     "artist": "Swedish House Mafia",
#     "artist_id": "1h6Cn3P4NGzXbaXidqURXs",
#     "artist_image": null,
#     "album": "Moth To A Flame (Adriatique Remix)",
#     "album_image": "https://i.scdn.co/image/ab67616d0000b273a812bacdaf59e037372e9336",
#     "popularity": 54
#   },
#   {
#     "track_id": "6KmkQvauDDoID3EV58itR1",
#     "track_name": "Love Is Eternity",
#     "artist": "Armin van Buuren",
#     "artist_id": "0SfsnGyD8FpIN4U4WCkBZ5",
#     "artist_image": null,
#     "album": "Breathe",
#     "album_image": "https://i.scdn.co/image/ab67616d0000b273d40158da4ccd26e0f315d8ed",
#     "popularity": 35
#   },
#   {
#     "track_id": "6h5y2LCqCQudsCarn61CNE",
#     "track_name": "Believe (feat. Goodboys)",
#     "artist": "ACRAZE",
#     "artist_id": "4pnp4w9g30yLfVIAFnZMRd",
#     "artist_image": null,
#     "album": "Believe (feat. Goodboys)",
#     "album_image": "https://i.scdn.co/image/ab67616d0000b273f65b1ca381b8025bb64133cd",
#     "popularity": 56
#   },
#   {
#     "track_id": "5Q9m03fBYtSlKwAUnfZ9RB",
#     "track_name": "Glow",
#     "artist": "Rebūke",
#     "artist_id": "113reBz1jA6rVxbXl55mlj",
#     "artist_image": null,
#     "album": "Glow / Void",
#     "album_image": "https://i.scdn.co/image/ab67616d0000b2738a3b6f82a230c74783ed709f",
#     "popularity": 52
#   },
#   {
#     "track_id": "4J7CKHCF3mdL4diUsmW8lq",
#     "track_name": "Under Control (feat. Hurts)",
#     "artist": "Calvin Harris",
#     "artist_id": "7CajNmpbOovFoOoasH2HaY",
#     "artist_image": null,
#     "album": "Motion",
#     "album_image": "https://i.scdn.co/image/ab67616d0000b2738fba5806a323efd272677c4d",
#     "popularity": 74
#   },
#   {
#     "track_id": "0JFNTfRWLqQ09z9ZHldX8d",
#     "track_name": "Where I'm From",
#     "artist": "Cassian",
#     "artist_id": "1ChtRJ3f4rbv4vtz87i6CD",
#     "artist_image": null,
#     "album": "Where I'm From",
#     "album_image": "https://i.scdn.co/image/ab67616d0000b2733670aebbd0bef618c674d703",
#     "popularity": 60
#   }
# ]

# %%
# UTILIZA GEMINI PARA ENRIQUECIMENTO DAS 10 PRIMEIRAS MÚSICAS

import os
from google import genai
import json
import re

# Configuração da chave
os.environ["GOOGLE_SECRET_API_KEY"] = "AIzaSyAtr3Mo8sDr36QB1MjRTEb4pDbOFAifAXA"
google_api_key = os.environ['GOOGLE_SECRET_API_KEY']

client = genai.Client(api_key=google_api_key)

test_batch = result_list

prompt = f"""
Você é um especialista em música. 
Para cada música listada abaixo, retorne em JSON os seguintes campos:

- track_id
- track_name
- artist
- album
- genre (gênero principal)
- subgenre (subgênero, se aplicável)
- danceability (0-1)
- energy (0-1)
- mood (ex.: energetic, calm, happy, sad)
- release_year (ano do lançamento, se conhecido)
- era (década: 1980s, 1990s, 2000s, 2010s, 2020s)
- lyrics_theme (tema predominante da letra, se conhecido)
- instrumentalness (0-1, grau de instrumentalidade)
- explicit (True/False)

Se algum valor for desconhecido, preencha com uma aproximação baseada no gênero da música.

Músicas:
{test_batch}

Devolva apenas o JSON como lista de objetos, sem explicações adicionais.
"""
client = genai.Client(api_key=google_api_key)

response = client.models.generate_content(model="gemini-2.5-flash", contents=[prompt])

response.text
# Out:
# '```json\n[\n  {\n    "track_id": "1yZBuUYcA0Ug7Y7ImNdhwt",\n    "track_name": "Zodiac",\n    "artist": "Agents Of Time",\n    "album": "Zodiac",\n    "genre": "Electronic",\n    "subgenre": "Melodic Techno",\n    "danceability": 0.8,\n    "energy": 0.85,\n    "mood": "Energetic, hypnotic, driving",\n    "release_year": 2021,\n    "era": "2020s",\n    "lyrics_theme": "Instrumental (minimal vocal samples)",\n    "instrumentalness": 0.95,\n    "explicit": false\n  },\n  {\n    "track_id": "2SbAoNQVqVkIuFTFV94Bdm",\n    "track_name": "Make It Better [ZAC & BAKKA (BR) Remix]",\n    "artist": "Dashdot",\n    "album": "Make It Better (Remixes Vol.1)",\n    "genre": "Electronic",\n    "subgenre": "Melodic House",\n    "danceability": 0.82,\n    "energy": 0.8,\n    "mood": "Uplifting, rhythmic, driving",\n    "release_year": 2023,\n    "era": "2020s",\n    "lyrics_theme": "Instrumental (minimal vocal snippets)",\n    "instrumentalness": 0.9,\n    "explicit": false\n  },\n  {\n    "track_id": "4vLdWFBi8WgA00nWPUHaLS",\n    "track_name": "All That Matters - ARTBAT Remix Radio Edit",\n    "artist": "Kölsch",\n    "album": "All That Matters (Artbat Remix)",\n    "genre": "Electronic",\n    "subgenre": "Melodic Techno",\n    "danceability": 0.78,\n    "energy": 0.85,\n    "mood": "Energetic, atmospheric, emotional",\n    "release_year": 2021,\n    "era": "2020s",\n    "lyrics_theme": "Existential, introspective (with subtle vocals)",\n    "instrumentalness": 0.8,\n    "explicit": false\n  },\n  {\n    "track_id": "6jYXP1jrYIHkEYglFgeL2Q",\n    "track_name": "Home",\n    "artist": "Adriatique",\n    "album": "Home",\n    "genre": "Electronic",\n    "subgenre": "Melodic House",\n    "danceability": 0.75,\n    "energy": 0.7,\n    "mood": "Evocative, atmospheric, deep",\n    "release_year": 2018,\n    "era": "2010s",\n    "lyrics_theme": "Instrumental (atmospheric vocal samples)",\n    "instrumentalness": 0.92,\n    "explicit": false\n  },\n  {\n    "track_id": "1G3kwVs3JHqN5UPiFXcAID",\n    "track_name": "Moth To A Flame (feat. The Weeknd) - Adriatique Remix",\n    "artist": "Swedish House Mafia",\n    "album": "Moth To A Flame (Adriatique Remix)",\n    "genre": "Electronic",\n    "subgenre": "Melodic Techno",\n    "danceability": 0.7,\n    "energy": 0.8,\n    "mood": "Intense, melancholic, nocturnal",\n    "release_year": 2022,\n    "era": "2020s",\n    "lyrics_theme": "Obsession, toxic love, longing",\n    "instrumentalness": 0.3,\n    "explicit": false\n  },\n  {\n    "track_id": "6KmkQvauDDoID3EV58itR1",\n    "track_name": "Love Is Eternity",\n    "artist": "Armin van Buuren",\n    "album": "Breathe",\n    "genre": "Electronic",\n    "subgenre": "Trance",\n    "danceability": 0.7,\n    "energy": 0.88,\n    "mood": "Euphoric, uplifting, energetic",\n    "release_year": 2019,\n    "era": "2010s",\n    "lyrics_theme": "Love, hope, connection",\n    "instrumentalness": 0.6,\n    "explicit": false\n  },\n  {\n    "track_id": "6h5y2LCqCQudsCarn61CNE",\n    "track_name": "Believe (feat. Goodboys)",\n    "artist": "ACRAZE",\n    "album": "Believe (feat. Goodboys)",\n    "genre": "Electronic",\n    "subgenre": "Tech House",\n    "danceability": 0.85,\n    "energy": 0.8,\n    "mood": "Energetic, celebratory, confident",\n    "release_year": 2022,\n    "era": "2020s",\n    "lyrics_theme": "Self-belief, perseverance, overcoming challenges",\n    "instrumentalness": 0.35,\n    "explicit": false\n  },\n  {\n    "track_id": "5Q9m03fBYtSlKwAUnfZ9RB",\n    "track_name": "Glow",\n    "artist": "Rebūke",\n    "album": "Glow / Void",\n    "genre": "Electronic",\n    "subgenre": "Techno",\n    "danceability": 0.8,\n    "energy": 0.88,\n    "mood": "Intense, driving, rhythmic, dark",\n    "release_year": 2023,\n    "era": "2020s",\n    "lyrics_theme": "Instrumental (minimal vocal samples)",\n    "instrumentalness": 0.95,\n    "explicit": false\n  },\n  {\n    "track_id": "4J7CKHCF3mdL4diUsmW8lq",\n    "track_name": "Under Control (feat. Hurts)",\n    "artist": ...

# %%
import json
import re

raw_text = response.text

# Remove markdown ```json ``` e aspas escapadas
clean_text = re.sub(r"```json|```", "", raw_text).replace('\\"', '"').strip()

# Regex para capturar todos os objetos {...} individualmente
matches = re.findall(r"\{.*?\}", clean_text, re.DOTALL)

enriched_tracks = []
for m in matches:
    try:
        obj = json.loads(m)
        enriched_tracks.append(obj)
    except json.JSONDecodeError:
        # Se falhar, podemos tentar corrigir vírgulas ou caracteres problemáticos
        m_fixed = re.sub(r",\s*}", "}", m)  # remove vírgulas finais
        m_fixed = re.sub(r",\s*\]", "]", m_fixed)  # remove vírgulas antes de colchetes
        try:
            obj = json.loads(m_fixed)
            enriched_tracks.append(obj)
        except json.JSONDecodeError:
            print("⚠️ Objeto ignorado por JSON inválido:", m[:60], "...")

print(f"✅ Total de objetos válidos: {len(enriched_tracks)}")

# Salva em arquivo JSON
if enriched_tracks:
    output_file = "retornoJSON/nilton_tracks_enriched.json"
    with open(output_file, "w", encoding="utf-8") as f:
        json.dump(enriched_tracks, f, ensure_ascii=False, indent=2)
    print(f"✅ Arquivo salvo em {output_file}")
# Out:
# ✅ Total de objetos válidos: 10
# ✅ Arquivo salvo em retornoJSON/nilton_tracks_enriched.json

# %%
#%pip install scikit-learn

# %%
#compara utilizando modelo 

import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# ===============================
# 1️⃣ Ler arquivos JSON
# ===============================
base_geral = pd.read_json("retornoJSON/df_tracks_enriched.json")
base_usuario = pd.read_json("retornoJSON/anderson_tracks_enriched.json")

# ===============================
# 2️⃣ Selecionar features relevantes
# ===============================
features_numericas = ['danceability', 'energy', 'instrumentalness']
features_textuais = ['genre', 'subgenre', 'mood', 'lyrih_cs_theme']

# ===============================
# 3️⃣ Normalizar features numéricas
# ===============================
scaler = StandardScaler()
X_base_num = scaler.fit_transform(base_geral[features_numericas])
X_user_num = scaler.transform(base_usuario[features_numericas])

# ===============================
# 4️⃣ Transformar textos em vetores TF-IDF
# ===============================
def combinar_textos(df):
    return (
        df['genre'].fillna('') + ' ' +
        df['subgenre'].fillna('') + ' ' +
        df['mood'].fillna('') + ' ' +
        df['lyrics_theme'].fillna('')
    )

tfidf = TfidfVectorizer(stop_words='english')
X_base_text = tfidf.fit_transform(combinar_textos(base_geral))
X_user_text = tfidf.transform(combinar_textos(base_usuario))

# ===============================
# 5️⃣ Combinar representações numéricas + textuais
# ===============================
from scipy.sparse import hstack

X_base_total = hstack([X_base_text, X_base_num])
X_user_total = hstack([X_user_text, X_user_num])

# ===============================
# 6️⃣ Calcular similaridade de cosseno
# ===============================
similaridade = cosine_similarity(X_user_total, X_base_total)

# média da similaridade de todas as músicas do usuário
media_sim = similaridade.mean(axis=0)

# ===============================
# 7️⃣ Ordenar top recomendações
# ===============================
base_geral['similaridade'] = media_sim
recomendacoes = base_geral.sort_values('similaridade', ascending=False)

# ===============================
# 8️⃣ Exibir top 10 músicas recomendadas
# ===============================
cols = ['track_name', 'artist', 'album', 'genre', 'subgenre', 'similaridade']
recomendacoes[cols].head(5)
# Out:
#                         track_name               artist  \
# 247                      Sandstorm               Darude
# 36           La Plena - W Sound 05              W Sound
# 333  Barbra Streisand - Radio Edit           Duck Sauce
# 314   One (Your Name) - Radio Edit  Swedish House Mafia
# 43               The Addams Family          Andrew Gold
#
#                                   album       genre  \
# 247   Before the Storm, Special Edition      Trance
# 36                La Plena (W Sound 05)  Electronic
# 333                    Barbra Streisand  Electronic
# 314                     One (Your Name)  Electronic
# 43   Halloween Howls: Fun & Scary Music     Novelty
#
#                             subgenre  similaridade
# 247  Hard Trance, Progressive Trance      0.536337
# 36                  Afro House/Dance      0.530789
# 333                      Disco House      0.518321
# 314                Progressive House      0.512859
# 43                      Instrumental      0.494233

# %%
# Salva o resultado de recomendacoes[cols].head(5) em um arquivo .json
recomendacoes[cols].head(5).to_json(
    "retornoJSON/recommendation_anderson.json",
    orient="records",
    force_ascii=False,
    indent=2
)
